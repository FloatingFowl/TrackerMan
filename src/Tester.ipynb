# %% [markdown]
# $$\bbox[5px,border:2px solid red]{Testing Graph }$$

# %%
import cv2, numpy as np, os, pickle
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
with open('pedestrian_detections.pkl', 'rb') as f:
    dct = pickle.load(f)

# %%
im = cv2.cvtColor(cv2.imread('img.png'), cv2.COLOR_BGR2RGB)
fig,ax = plt.subplots(1)
ax.imshow(im)

ind = (dct['fr'] == 1)
print(ind.sum())
for i in range(len(ind)):
    if ind[i] == True and dct['r'][i] > -4:
        rect = patches.Rectangle((dct['x'][i],dct['y'][i]),dct['w'][i],dct['h'][i],linewidth=1,edgecolor='r',facecolor='none')
        ax.add_patch(rect)

plt.savefig('eg.eps',bbox_inches='tight')
plt.show()
# Out:
# 102

# %%
from importlib import reload
import grapher
reload(grapher)
grapher
ndct = grapher.graphMaker(dct);
